# %%
import string

import numpy as np
import pandas as pd
import plotly.express as px
from numpy.random import RandomState

from src.extraction.jsonl_data_reader import JsonlDataReader

seed = 7
random_state = RandomState(seed=seed)
np.random.seed(seed)

# %%
from src.utils.path_getter import PathGetter

results_df = pd.read_parquet(PathGetter.get_data_directory()/'experiments2.parquet')

# %%
results_df[results_df['vectorizer'] == 'W2vVectorizer']
# Out:
#             pretokenizer  remove_citations  remove_duplicates  \
# 8     SimplePreprocessor              True               True
# 18    SimplePreprocessor              True               True
# 28    SimplePreprocessor              True               True
# 38    SimplePreprocessor              True               True
# 48    SimplePreprocessor              True               True
# ...                  ...               ...                ...
# 1278  SimplePreprocessor             False              False
# 1288  SimplePreprocessor             False              False
# 1298  SimplePreprocessor             False              False
# 1308  SimplePreprocessor             False              False
# 1318  SimplePreprocessor             False              False
#
#                    tokenizer replace_numbers remove_stopwords lemmatize  \
# 8             SpacyTokenizer            True             True      True
# 18            SpacyTokenizer            True             True      True
# 28            SpacyTokenizer            True             True      True
# 38            SpacyTokenizer            True             True     False
# 48            SpacyTokenizer            True             True     False
# ...                      ...             ...              ...       ...
# 1278  SentencePieceTokenizer            None             None      None
# 1288  SentencePieceTokenizer            None             None      None
# 1298  SentencePieceTokenizer            None             None      None
# 1308  SentencePieceTokenizer            None             None      None
# 1318  SentencePieceTokenizer            None             None      None
#
#          post_tokenizer     vectorizer ngram_range binary          model  \
# 8     NullPostTokenizer  W2vVectorizer        None   None  AbstractModel
# 18        PhraserMerger  W2vVectorizer        None   None  AbstractModel
# 28        PhraserMerger  W2vVectorizer        None   None  AbstractModel
# 38    NullPostTokenizer  W2vVectorizer        None   None  AbstractModel
# 48        PhraserMerger  W2vVectorizer        None   None  AbstractModel
# ...                 ...            ...         ...    ...            ...
# 1278      PhraserMerger  W2vVectorizer        None   None  AbstractModel
# 1288      PhraserMerger  W2vVectorizer        None   None  AbstractModel
# 1298  NullPostTokenizer  W2vVectorizer        None   None  AbstractModel
# 1308      PhraserMerger  W2vVectorizer        None   None  AbstractModel
# 1318      PhraserMerger  W2vVectorizer        None   None  AbstractModel
#
#      model_name  train_f1    dev_f1   test_f1  num_gram  vocab_size
# 8            LR  0.670272  0.653076  0.638851       NaN         NaN
# 18           LR  0.664103  0.643700  0.651177       1.0         NaN
# 28           LR  0.659143  0.619486  0.620719       2.0         NaN
# 38           LR  0.662035  0.651118  0.645175       NaN         NaN
# 48           LR  0.654246  0.628811  0.639881       1.0         NaN
# ...         ...       ...       ...       ...       ...         ...
# 1278         LR  0.344085  0.324265  0.309044       1.0      5000.0
# 1288         LR  0.293498  0.285431  0.277823       2.0      5000.0
# 1298         LR  0.517445  0.477691  0.504881       NaN     10000.0
# 1308         LR  0.408092  0.365876  0.385936       1.0     10000.0
# 1318         LR  0.365721  0.362711  0.332887       2.0     10000.0
#
# [132 rows x 18 columns]
